# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
from sklearn.ensemble import IsolationForest

import folium
from IPython.display import display

from sklearn.preprocessing import StandardScaler

import matplotlib.pyplot as plt

from sklearn.decomposition import PCA

from sklearn.cluster import KMeans
from sklearn.model_selection import train_test_split


import seaborn as sns

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
df_info = pd.read_csv('cc_info.csv')
df_info.head()
# Out:
#         credit_card      city state  zipcode  credit_card_limit
# 0  1280981422329509    Dallas    PA    18612               6000
# 1  9737219864179988   Houston    PA    15342              16000
# 2  4749889059323202    Auburn    MA     1501              14000
# 3  9591503562024072   Orlando    WV    26412              18000
# 4  2095640259001271  New York    NY    10001              20000

# %%
df_trans = pd.read_csv('transactions.csv')
df_trans.head()
# Out:
#         credit_card                 date  transaction_dollar_amount  \
# 0  1003715054175576  2015-09-11 00:32:40                      43.78
# 1  1003715054175576  2015-10-24 22:23:08                     103.15
# 2  1003715054175576  2015-10-26 18:19:36                      48.55
# 3  1003715054175576  2015-10-22 19:41:10                     136.18
# 4  1003715054175576  2015-10-26 20:08:22                      71.82
#
#         Long        Lat
# 0 -80.174132  40.267370
# 1 -80.194240  40.180114
# 2 -80.211033  40.313004
# 3 -80.174138  40.290895
# 4 -80.238720  40.166719

# %%
df = df_info.merge(df_trans, how = 'left', left_on = 'credit_card', right_on = 'credit_card')

# %%
# Sample only 10% of the data
df = df.sample(frac=0.1, random_state=14)

# %%
df.columns
# Out:
# Index(['credit_card', 'city', 'state', 'zipcode', 'credit_card_limit', 'date',
#        'transaction_dollar_amount', 'Long', 'Lat'],
#       dtype='object')

# %%
df.isna().sum()
# Out:
# credit_card                  0
# city                         0
# state                        0
# zipcode                      0
# credit_card_limit            0
# date                         0
# transaction_dollar_amount    0
# Long                         0
# Lat                          0
# dtype: int64

# %%
filtered_df = df[df['credit_card'] == 1280981422329509]

# Create a map centered around the average location of the filtered data
if not filtered_df.empty:
    initial_location = [filtered_df['Lat'].mean(), filtered_df['Long'].mean()]
    transaction_map = folium.Map(location=initial_location, zoom_start=2)

    # Add markers for each transaction in the filtered data
    for index, row in filtered_df.iterrows():
        folium.Marker(
            location=[row['Lat'], row['Long']],
            tooltip=f"City: {row['city']}, State: {row['state']}",
            popup=f"Transaction: ${row['transaction_dollar_amount']} on {row['date']}"
        ).add_to(transaction_map)

    display(transaction_map)
else:
    print("No data found for the given credit card.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8bb16d4eeea9c300aa213bd9e49cb0d0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8bb16d4eeea9c300aa213bd9e49cb0d0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8bb16d4eeea9c300aa213bd9e49cb0d0 = L.map(
#                 &quot;map_8bb16d4eeea9c300aa213bd9e49cb0d0&quot;,
#                 {
#                     center: [42.038583128704, -73.23997331441207],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6264bbe30a3af1a5acea34409f2036ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_6264bbe30a3af1a5acea34409f2036ea.addTo(map_8bb16d4eeea9c300aa213bd9e49cb0d0);
#
#
#             var marker_ca20169717f1ab9cc0be44a1db5b7fdf = L.marker(
#                 [41.3063130913948, -75.9368012278168],
#                 {}
#             ).addTo(map_8bb16d4eeea9c300aa213bd9e49cb0d0);
#
#
#         var popup_1f9c71031702cc4b565de107291acb8e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_cc36779e44028b5a2f2fae1340e2e0bc = $(`&lt;div id=&quot;html_cc36779e44028b5a2f2fae1340e2e0bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $8.14 on 2015-08-20 18:08:45&lt;/div&gt;`)[0];
#                 popup_1f9c71031702cc4b565de107291acb8e.setContent(html_cc36779e44028b5a2f2fae1340e2e0bc);
#
#
#
#         marker_ca20169717f1ab9cc0be44a1db5b7fdf.bindPopup(popup_1f9c71031702cc4b565de107291acb8e)
#         ;
#
#
#
#
#             marker_ca20169717f1ab9cc0be44a1db5b7fdf.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_cb4be8cbd91ddc78fc677a7bcbe80e7c = L.marker(
#                 [41.2966409463158, -76.0183170188432],
#                 {}
#             ).addTo(map_8bb16d4eeea9c300aa213bd9e49cb0d0);
#
#
#         var popup_40606366685a36126771a6f01ce970db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b8a3fa7453629381ed7abfb421bd7e38 = $(`&lt;div id=&quot;html_b8a3fa7453629381ed7abfb421bd7e38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $41.53 on 2015-08-31 19:16:27&lt;/div&gt;`)[0];
#                 popup_40606366685a36126771a6f01ce970db.setContent(html_b8a3fa7453629381ed7abfb421bd7e38);
#
#
#
#         marker_cb4be8cbd91ddc78fc677a7bcbe80e7c.bindPopup(popup_40606366685a36126771a6f01ce970db)
#         ;
#
#
#
#
#             marker_cb4be8cbd91ddc78fc677a7bcbe80e7c.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_e4e4ff5865ebef339727313f5f4fb41f = L.marker(
#                 [41.349526258663, -75.98872286357779],
#                 {}
#             ).addTo(map_8bb16d4eeea9c300aa213bd9e49cb0d0);
#
#
#         var popup_3ff9e176aae9726ef2550e6b7d92e56a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fd5edbf5fa8e004c0b4202e86c05bf2b = $(`&lt;div id=&quot;html_fd5edbf5fa8e004c0b4202e86c05bf2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $44.52 on 2015-10-15 16:48:33&lt;/div&gt;`)[0];
#                 popup_3ff9e176aae9726ef2550e6b7d92e56a.setContent(html_fd5edbf5fa8e004c0b4202e86c05bf2b);
#
#
#
#         marker_e4e4ff5865ebef339727313f5f4fb41f.bindPopup(popup_3ff9e176aae9726ef2550e6b7d92e56a)
#         ;
#
#
#
#
#             marker_e4e4ff5865ebef339727313f5f4fb41f.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_aee03a950696e5e2eb4c17369111037c = L.marker(
#                 [41.321202523492204, -76.0363474416275],
#                 {}
#             ).addTo(map_8bb16d4eeea9c300aa213bd9e49cb0d0);
#
#
#         var popup_eac3375bd25c1422cbbec25b53c0fcd8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_dd1c9e80ef23bfa37d3b400bf487474c = $(`&lt;div id=&quot;html_dd1c9e80ef23bfa37d3b400bf487474c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $43.75 on 2015-09-23 17:46:27&lt;/div&gt;`)[0];
#                 popup_eac3375bd25c1422cbbec25b53c0fcd8.setContent(html_dd1c9e80ef23bfa37d3b400bf487474c);
#
#
#
#         marker_aee03a950696e5e2eb4c17369111037c.bindPopup(popup_eac3375bd25c1422cbbec25b53c0fcd8)
#         ;
#
#
#
#
#             marker_aee03a950696e5e2eb4c17369111037c.bindTooltip(

# %%
# Convert Date to Number
unix_timestamps = []

for date in df_trans['date']:
    datetime_obj = pd.to_datetime(date)
    unix_timestamp = int(datetime_obj.timestamp())
    unix_timestamps.append(unix_timestamp)

# Add the converted dates as a new column
df_trans['unix_timestamp'] = unix_timestamps
df_trans.drop(['date'], axis=1, inplace=True)


# Standardization
df_trans_columns = df_trans.columns
std = StandardScaler()
df_trans = std.fit_transform(df_trans)
df_trans = pd.DataFrame(df_trans, columns = df_trans_columns)

# %%
model = IsolationForest(n_estimators=100, max_samples=0.5,
                        contamination='auto', max_features=1.0, bootstrap=False, n_jobs=None,
                        verbose=1, random_state=2020)
model.fit(df_trans)
# Out:
# IsolationForest(max_samples=0.5, random_state=2020, verbose=1)

# %%
Y = model.predict(df_trans)

# %%
Y_series = pd.Series(Y)
print(Y_series.value_counts())
# Out:
#  1    282758
# -1     11830
# dtype: int64
