# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

import folium
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt
import shap
from tabulate import tabulate

# %% [markdown]
# ---
# ### Explore the data
# ***There are two datasets; let's display each of them:***

# %%
df_info = pd.read_csv('cc_info.csv')
df_info.head()
# Out:
#         credit_card      city state  zipcode  credit_card_limit
# 0  1280981422329509    Dallas    PA    18612               6000
# 1  9737219864179988   Houston    PA    15342              16000
# 2  4749889059323202    Auburn    MA     1501              14000
# 3  9591503562024072   Orlando    WV    26412              18000
# 4  2095640259001271  New York    NY    10001              20000

# %%
df_trans = pd.read_csv('transactions.csv')
df_trans.head()
# Out:
#         credit_card                 date  transaction_dollar_amount  \
# 0  1003715054175576  2015-09-11 00:32:40                      43.78
# 1  1003715054175576  2015-10-24 22:23:08                     103.15
# 2  1003715054175576  2015-10-26 18:19:36                      48.55
# 3  1003715054175576  2015-10-22 19:41:10                     136.18
# 4  1003715054175576  2015-10-26 20:08:22                      71.82
#
#         Long        Lat
# 0 -80.174132  40.267370
# 1 -80.194240  40.180114
# 2 -80.211033  40.313004
# 3 -80.174138  40.290895
# 4 -80.238720  40.166719

# %%
df = df_info.merge(df_trans, how = 'left', left_on = 'credit_card', right_on = 'credit_card')

# %% [markdown]
# ***The data is too large. Let's work with only 10% of it to reduce the runtime.***

# %%
# Sample only 10% of the data
df = df.sample(frac=0.1, random_state=14)

# %%
df.columns
# Out:
# Index(['credit_card', 'city', 'state', 'zipcode', 'credit_card_limit', 'date',
#        'transaction_dollar_amount', 'Long', 'Lat'],
#       dtype='object')

# %% [markdown]
# Check if there are any null values in the dataset that we need to address:

# %%
df.isna().sum()
# Out:
# credit_card                  0
# city                         0
# state                        0
# zipcode                      0
# credit_card_limit            0
# date                         0
# transaction_dollar_amount    0
# Long                         0
# Lat                          0
# dtype: int64

# %% [markdown]
# ---
# ## Explanation by data points comparison

# %% [markdown]
# ***Let's display the transaction data for a given credit card to check for any anomalies that might indicate fraudulent activity.***

# %%
filtered_df = df[df['credit_card'] == 1280981422329509]

# Create a map centered around the average location of the filtered data
if not filtered_df.empty:
    initial_location = [filtered_df['Lat'].mean(), filtered_df['Long'].mean()]
    transaction_map = folium.Map(location=initial_location, zoom_start=2)

    # Add markers for each transaction in the filtered data
    for index, row in filtered_df.iterrows():
        folium.Marker(
            location=[row['Lat'], row['Long']],
            tooltip=f"City: {row['city']}, State: {row['state']}",
            popup=f"Transaction: ${row['transaction_dollar_amount']} on {row['date']}"
        ).add_to(transaction_map)

    display(transaction_map)
else:
    print("No data found for the given credit card.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4b2bac4e82668eb96b0ad36f16883b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4b2bac4e82668eb96b0ad36f16883b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4b2bac4e82668eb96b0ad36f16883b4 = L.map(
#                 &quot;map_c4b2bac4e82668eb96b0ad36f16883b4&quot;,
#                 {
#                     center: [42.038583128704, -73.23997331441205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36f0bd1d51efb5bcace8a4a9aac00e56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_36f0bd1d51efb5bcace8a4a9aac00e56.addTo(map_c4b2bac4e82668eb96b0ad36f16883b4);
#
#
#             var marker_761065bea5abb75e94d958d17ce1cea1 = L.marker(
#                 [41.3063130913948, -75.9368012278168],
#                 {}
#             ).addTo(map_c4b2bac4e82668eb96b0ad36f16883b4);
#
#
#         var popup_25803b16c82be2b9bf2d93797ae74372 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f08f88dbb426693c2c853fb790b9cf3 = $(`&lt;div id=&quot;html_0f08f88dbb426693c2c853fb790b9cf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $8.14 on 2015-08-20 18:08:45&lt;/div&gt;`)[0];
#                 popup_25803b16c82be2b9bf2d93797ae74372.setContent(html_0f08f88dbb426693c2c853fb790b9cf3);
#
#
#
#         marker_761065bea5abb75e94d958d17ce1cea1.bindPopup(popup_25803b16c82be2b9bf2d93797ae74372)
#         ;
#
#
#
#
#             marker_761065bea5abb75e94d958d17ce1cea1.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_f9aacef9e00e754bd774dcc0928d9798 = L.marker(
#                 [41.2966409463158, -76.0183170188432],
#                 {}
#             ).addTo(map_c4b2bac4e82668eb96b0ad36f16883b4);
#
#
#         var popup_4157d42e84e3b75e74b693661ee82fc8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7b71b8deb3e3cbf85987370905bba439 = $(`&lt;div id=&quot;html_7b71b8deb3e3cbf85987370905bba439&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $41.53 on 2015-08-31 19:16:27&lt;/div&gt;`)[0];
#                 popup_4157d42e84e3b75e74b693661ee82fc8.setContent(html_7b71b8deb3e3cbf85987370905bba439);
#
#
#
#         marker_f9aacef9e00e754bd774dcc0928d9798.bindPopup(popup_4157d42e84e3b75e74b693661ee82fc8)
#         ;
#
#
#
#
#             marker_f9aacef9e00e754bd774dcc0928d9798.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0f5dde0e44e6f1fdde8cd07774700019 = L.marker(
#                 [41.349526258663, -75.9887228635778],
#                 {}
#             ).addTo(map_c4b2bac4e82668eb96b0ad36f16883b4);
#
#
#         var popup_62773e8c3943869a5bb70d145f4cd0bc = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4c97f2b2b63a6399d521dacb8a046c24 = $(`&lt;div id=&quot;html_4c97f2b2b63a6399d521dacb8a046c24&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $44.52 on 2015-10-15 16:48:33&lt;/div&gt;`)[0];
#                 popup_62773e8c3943869a5bb70d145f4cd0bc.setContent(html_4c97f2b2b63a6399d521dacb8a046c24);
#
#
#
#         marker_0f5dde0e44e6f1fdde8cd07774700019.bindPopup(popup_62773e8c3943869a5bb70d145f4cd0bc)
#         ;
#
#
#
#
#             marker_0f5dde0e44e6f1fdde8cd07774700019.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_58cb9ed5df51e67bfccf306620c59704 = L.marker(
#                 [41.3212025234922, -76.0363474416275],
#                 {}
#             ).addTo(map_c4b2bac4e82668eb96b0ad36f16883b4);
#
#
#         var popup_c0e1fc7472c2b48f5095d9a7dbd83fc5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4b18c49b548f99eae36dd7c2a4a39643 = $(`&lt;div id=&quot;html_4b18c49b548f99eae36dd7c2a4a39643&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $43.75 on 2015-09-23 17:46:27&lt;/div&gt;`)[0];
#                 popup_c0e1fc7472c2b48f5095d9a7dbd83fc5.setContent(html_4b18c49b548f99eae36dd7c2a4a39643);
#
#
#
#         marker_58cb9ed5df51e67bfccf306620c59704.bindPopup(popup_c0e1fc7472c2b48f5095d9a7dbd83fc5)
#         ;
#
#
#
#
#             marker_58cb9ed5df51e67bfccf306620c59704.bindTooltip(

# %%
# Extract the 'transaction_dollar_amount' column from filtered_df
transaction_amounts = filtered_df['transaction_dollar_amount']

# Plot a histogram of transaction dollar amounts
plt.hist(transaction_amounts, bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transaction Dollar Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Transaction Dollar Amounts')

# Show the plot
plt.show()

# %% [markdown]
# ---
# ## ***Isolation Forests***- *In-Model Technique*
# ***For simplicity, from now on, we will use only the transactions dataset.***

# %%
# Convert Date to Number
unix_timestamps = []

for date in df_trans['date']:
    datetime_obj = pd.to_datetime(date)
    unix_timestamp = int(datetime_obj.timestamp())
    unix_timestamps.append(unix_timestamp)


# Add the converted dates as a new column
df_trans['unix_timestamp'] = unix_timestamps
timestamp_date_map = dict(zip(df_trans['unix_timestamp'], df_trans['date']))
df_trans.drop(['date'], axis=1, inplace=True)



# # Standardization
# df_trans_columns = df_trans.columns
# std = StandardScaler()
# df_trans = std.fit_transform(df_trans)
# df_trans = pd.DataFrame(df_trans, columns = df_trans_columns)

# %%
model = IsolationForest(n_estimators=100, max_samples=0.5,
                        contamination='auto', max_features=1.0, bootstrap=False, n_jobs=None,
                        verbose=1, random_state=2020)
model.fit(df_trans)
# Out:
# IsolationForest(max_samples=0.5, random_state=2020, verbose=1)

# %%
predictions = model.predict(df_trans)

# %%
Y_series = pd.Series(predictions)
print(Y_series.value_counts())
# Out:
#  1    282318
# -1     12270
# Name: count, dtype: int64

# %% [markdown]
# ***1: Normal data points.      -1: Anomalies.***

# %% [markdown]
# ---
# ## Counter Examples

# %%
def display_anomaly_and_counterexamples(selected_anomaly_index):
    # Find Similar Counterexamples
    selected_anomaly = df_trans.iloc[selected_anomaly_index]
    similarities = np.linalg.norm(df_trans - selected_anomaly, axis=1)
    sorted_indices = np.argsort(similarities)
    
    num_counterexamples = 3
    counterexample_indices = []
    
    for idx in sorted_indices:
        if len(counterexample_indices) >= num_counterexamples:
            break
        if predictions[idx] == 1 and idx != selected_anomaly_index:  
            counterexample_indices.append(idx)
    
    from tabulate import tabulate
    
    # Display the anomaly and its counterexamples
    print("Anomaly:")
    anomaly_timestamp = df_trans.iloc[selected_anomaly_index]['unix_timestamp']
    anomaly_date = timestamp_date_map[anomaly_timestamp]
    anomaly_data = df_trans.iloc[selected_anomaly_index].to_frame().transpose()
    anomaly_data.drop('unix_timestamp', axis=1, inplace=True)
    anomaly_data['date'] = anomaly_date
    print(tabulate(anomaly_data, headers='keys', tablefmt='grid', floatfmt=".8f"))
    print(f"\n\n")
    
    print("Counterexamples (Similar to Anomaly but Not Anomalies):")
    for idx in counterexample_indices:
        counterexample_timestamp = df_trans.iloc[idx]['unix_timestamp']
        counterexample_date = timestamp_date_map[counterexample_timestamp]
        counterexample_data = df_trans.iloc[idx].to_frame().transpose()
        counterexample_data.drop('unix_timestamp', axis=1, inplace=True)
        counterexample_data['date'] = counterexample_date
        print(tabulate(counterexample_data, headers='keys', tablefmt='grid', floatfmt=".8f"))
        print(f"\n")

# %%
anomaly_indices = np.where(predictions == -1)[0]

display_anomaly_and_counterexamples(anomaly_indices[2])
# Out:
# Anomaly:
# +----+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |    |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +====+===========================+=============================+==============+=============+=====================+
# | 84 | 1003715054175576.00000000 |                995.35000000 | -80.12676042 | 40.22562626 | 2015-09-11 19:50:02 |
# +----+---------------------------+-----------------------------+--------------+-------------+---------------------+
#
#
#
# Counterexamples (Similar to Anomaly but Not Anomalies):
# +-----+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |     |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +=====+===========================+=============================+==============+=============+=====================+
# | 167 | 1003715054175576.00000000 |                 70.12000000 | -80.23172307 | 40.18718129 | 2015-09-11 19:36:52 |
# +-----+---------------------------+-----------------------------+--------------+-------------+---------------------+
#
#
# +----+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |    |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +====+===========================+=============================+==============+=============+=====================+
# |  9 | 1003715054175576.00000000 |                 57.95000000 | -80.28752836 | 40.26787366 | 2015-09-11 18:59:04 |
# +----+---------------------------+-----------------------------+--------------+-------------+---------------------+
#
#
# +-----+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |     |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +=====+===========================+=============================+==============+=============+=====================+
# | 149 | 1003715054175576.00000000 |                 47.76000000 | -80.16347933 | 40.30652336 | 2015-09-11 22:08:21 |
# +-----+---------------------------+-----------------------------+--------------+-------------+---------------------+

# %% [markdown]
# *As we can see, **most of the values are the same**: the location of the transaction is pretty consistent, and all the transactions were made on the same day. **The only significant difference is the transaction dollar amount**, and this is probably the reason why this transaction was tagged as an anomaly.*

# %%
display_anomaly_and_counterexamples(anomaly_indices[120])
# Out:
# Anomaly:
# +------+---------------------------+-----------------------------+---------------+-------------+---------------------+
# |      |               credit_card |   transaction_dollar_amount |          Long |         Lat | date                |
# +======+===========================+=============================+===============+=============+=====================+
# | 1249 | 1087468642191606.00000000 |                107.04000000 | -121.77613742 | 47.45197516 | 2015-08-13 21:02:53 |
# +------+---------------------------+-----------------------------+---------------+-------------+---------------------+
#
#
#
# Counterexamples (Similar to Anomaly but Not Anomalies):
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |      |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +======+===========================+=============================+==============+=============+=====================+
# | 1275 | 1089479586475600.00000000 |                 77.31000000 | -78.81861917 | 42.89080014 | 2015-08-13 23:24:48 |
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+
#
#
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |      |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +======+===========================+=============================+==============+=============+=====================+
# | 1278 | 1089479586475600.00000000 |                 47.38000000 | -78.86619733 | 42.90003678 | 2015-08-13 15:05:21 |
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+
#
#
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+
# |      |               credit_card |   transaction_dollar_amount |         Long |         Lat | date                |
# +======+===========================+=============================+==============+=============+=====================+
# | 1377 | 1089479586475600.00000000 |                 48.77000000 | -78.84598253 | 42.94489527 | 2015-08-13 23:14:51 |
# +------+---------------------------+-----------------------------+--------------+-------------+---------------------+

# %% [markdown]
# *In this example, this transaction was likely tagged as an anomaly due to a **combination of two aspects: the transaction dollar amount and location**. The difference in dollar amount between the anomaly and counterexamples is less significant than in the previous example. However, in this case, there is also a significant difference in location, even though all transactions were made on the same day. This combination of differences likely caused this transaction to be tagged as an anomaly.*

# %% [markdown]
# ---
# ## Algorithm

# %% [markdown]
# ### ***Input***
# **D**- Dataset
# **s**- Anomaly Sample
# **k**- Number of Neighbors
# **m**- Explanation Score Metric
#
#
# ### ***Output***
# **D'**- Explaining Dataset
# **F_diff**- Anomaly Features

# %%
from sklearn.neighbors import NearestNeighbors

OMEGA_1 = 0.5
OMEGA_2 = 0.5
OMEGA_3 = 0.5
K = 3

# %%
# Identifies the n most similar samples to a given sample from the dataset D based on the specified filtered features using knn.
def knn_preds(D, filtered_features, sample):
    X = D[filtered_features]
    nn = NearestNeighbors(n_neighbors=K)
    nn.fit(X)
    
    _, indices = nn.kneighbors([sample[filtered_features]])
    similar_indices = indices[0]
    similar_samples = D.iloc[similar_indices]
    return similar_samples


# Explains how well D' explains a given sample (s) as an anomaly
def explanation_score(D_prime, s, F, F_diff, F_sim):
    term_1 = (OMEGA_1 / len(D_prime)) * sum(sim(D_prime, r, F) for idx, r in D_prime.iterrows()) # Measures the similarity between the subset D′ and a row r in D′
    term_2 = OMEGA_2 * sim(D_prime, s, F_sim) # Measures the similarity restricted to the features in 𝐹_𝑠𝑖𝑚
    term_3 = OMEGA_3 * sim(D_prime, s, F_diff) # Measures the similarity restricted to the features in 𝐹_𝑑𝑖𝑓𝑓
    
    result = term_1 + term_2 - term_3
    return result

# Euclidean distances between D_prime and a sample (s) based on the specified features (features).
def sim(D_prime, s, features):
    mean_vector = np.mean(D_prime, axis=0)
    norm_value = np.linalg.norm(mean_vector - s)
    s_E = 1 / (1 + norm_value)
    print(s_E)
    return s_E

# %%
def algo(D,s,m):
    BF_diff = []
    BSG = 0
    S = D
    F = D.columns

    for feature in F:
        BS = 0
        BF = None
        F_wo_BF_diff = [col for col in F if col not in BF_diff]
        for col in F_wo_BF_diff:
            # F_sim ∪ F_diff = F, F_sim ∩ F_diff = ∅
            F_diff = BF_diff + [col]
            F_sim = [f for f in F if f not in F_diff]
            
            F_wo_F_diff = [col for col in F if col not in F_diff] # [1, . . . , |F|]/BF_diff
            D_prime = knn_preds(D, F_wo_F_diff, s) # KNN.fit(D, F/F_diff ).predict(s)
            scores = m(D_prime, s, F, F_diff, F_sim) # Euclidean distance
            
            if scores > BS:
                BS = scores
                BF = col

# %%
anomaly_example = df_trans.iloc[anomaly_indices[120]]
df_and_preds = df_trans
df_and_preds['is_anomaly'] = predictions

algo(df_trans , anomaly_example, explanation_score)
# Out:
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 4.603317917834258e-16
# 4.632848720599656e-14
# 4.558028174885931e-16
# 4.603317917834258e-16
# 4.603317917834258e-16
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# 5.684455855455819e-06
# 3.829417328605461e-06
# 2.2880485310261817e-06
# 5.684455855455819e-06
# 5.684455855455819e-06
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 4.603317917834258e-16
# 4.632848720599656e-14
# 4.558028174885931e-16
# 4.603317917834258e-16
# 4.603317917834258e-16
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# 5.684455855455819e-06
# 3.829417328605461e-06
# 2.2880485310261817e-06
# 5.684455855455819e-06
# 5.684455855455819e-06
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 4.603317917834258e-16
# 4.632848720599656e-14
# 4.558028174885931e-16
# 4.603317917834258e-16
# 4.603317917834258e-16
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 5.684455855455819e-06
# 3.829417328605461e-06
# 2.2880485310261817e-06
# 5.684455855455819e-06
# 5.684455855455819e-06
# C:\Users\User\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but NearestNeighbors was fitted with feature names
#   warnings.warn(
# 0.000203361323031729
# 0.00017463179447087203
# 9.396135417204571e-05
# 0.000203361323031729
# 0.000203361323031729
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[314], line 5
#       2 df_and_preds = df_trans
#       3 df_and_preds['is_anomaly'] = predictions
# ----> 5 algo(df_trans , anomaly_example, explanation_score)
#
# Cell In[313], line 16, in algo(D, s, m)
#      14 F_sim = [f for f in F if f not in F_diff]
#      15 F_wo_F_diff = [col for col in F if col not in F_diff] # [1, . . . , |F|]/BF_diff
# ---> 16 D_prime = knn_preds(D, F_wo_F_diff, s) # KNN.fit(D, F/F_diff ).predict(s)
#      17 scores = m(D_prime, s, F, F_diff, F_sim)
#      18 scores = 1
#
# Cell In[312], line 5, in knn_preds(D, filtered_features, sample)
#       3 X = D[filtered_features]
#       4 nn = NearestNeighbors(n_neighbors=K)
# ----> 5 nn.fit(X)
#       7 _, indices = nn.kneighbors([sample[filtered_features]])
#       8 similar_indices = indices[0]
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\neighbors\_unsupervised.py:175, in NearestNeighbors.fit(self, X, y)
#     154 @_fit_context(
#     155     # NearestNeighbors.metric is not validated yet
#     156     prefer_skip_nested_validation=False
#     157 )
#     158 def fit(self, X, y=None):
#     159     """Fit the nearest neighbors estimator from the training dataset.
#     160
#     161     Parameters
#    (...)
#     173         The fitted nearest neighbors estimator.
#     174     """
# --> 175     return self._fit(X)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\neighbors\_base.py:683, in NeighborsBase._fit(self, X, y)
#     673     if (
#     674         self.effective_metric_ == "minkowski"
#     675         and self.effective_metric_params_.get("w") is not None
#     676     ):
#     677         raise ValueError(
#     678             "algorithm='kd_tree' is not valid for "
#     679             "metric='minkowski' with a weight parameter 'w': "
#     680             "try algorithm='ball_tree' "
#     681             "or algorithm='brute' instead."
#     682         )
# --> 683     self._tree = KDTree(
#     684         X,
#     685         self.leaf_size,
#     686         metric=self.effective_metric_,
#     687         **self.effective_metric_params_,
#     688     )
#     689 elif self._fit_method == "brute":
#     690     self._tree = None
#
# KeyboardInterrupt:

# %% [markdown]
# ---
# ## Explanation by feature importance

# %%
X_train_scaled_df = pd.DataFrame(df_trans, columns=df_trans.columns)

shap_sample = X_train_scaled_df.sample(500)
explainer = shap.Explainer(model.predict, shap_sample)
shap_values = explainer(shap_sample)
shap_values.feature_names = X_train_scaled_df.columns.tolist()
shap.plots.beeswarm(shap_values)

# %%
anomaly_indices = Y_series[Y_series == -1].index
anomaly_example_idx = anomaly_indices[0]

# %%
shap.plots.bar(explainer(X_train_scaled_df)[anomaly_example_idx])
