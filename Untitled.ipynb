# %% [markdown]
# ### Imports

# %%
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import IsolationForest

import folium
from IPython.display import display
import seaborn as sns
import matplotlib.pyplot as plt
import shap

# %% [markdown]
# ---
# ### Explore the data
# ***There are two datasets; let's display each of them:***

# %%
df_info = pd.read_csv('cc_info.csv')
df_info.head()
# Out:
#         credit_card      city state  zipcode  credit_card_limit
# 0  1280981422329509    Dallas    PA    18612               6000
# 1  9737219864179988   Houston    PA    15342              16000
# 2  4749889059323202    Auburn    MA     1501              14000
# 3  9591503562024072   Orlando    WV    26412              18000
# 4  2095640259001271  New York    NY    10001              20000

# %%
df_trans = pd.read_csv('transactions.csv')
df_trans.head()
# Out:
#         credit_card                 date  transaction_dollar_amount  \
# 0  1003715054175576  2015-09-11 00:32:40                      43.78
# 1  1003715054175576  2015-10-24 22:23:08                     103.15
# 2  1003715054175576  2015-10-26 18:19:36                      48.55
# 3  1003715054175576  2015-10-22 19:41:10                     136.18
# 4  1003715054175576  2015-10-26 20:08:22                      71.82
#
#         Long        Lat
# 0 -80.174132  40.267370
# 1 -80.194240  40.180114
# 2 -80.211033  40.313004
# 3 -80.174138  40.290895
# 4 -80.238720  40.166719

# %%
df = df_info.merge(df_trans, how = 'left', left_on = 'credit_card', right_on = 'credit_card')

# %% [markdown]
# ***The data is too large. Let's work with only 10% of it to reduce the runtime.***

# %%
# Sample only 10% of the data
df = df.sample(frac=0.1, random_state=14)

# %%
df.columns
# Out:
# Index(['credit_card', 'city', 'state', 'zipcode', 'credit_card_limit', 'date',
#        'transaction_dollar_amount', 'Long', 'Lat'],
#       dtype='object')

# %% [markdown]
# Check if there are any null values in the dataset that we need to address:

# %%
df.isna().sum()
# Out:
# credit_card                  0
# city                         0
# state                        0
# zipcode                      0
# credit_card_limit            0
# date                         0
# transaction_dollar_amount    0
# Long                         0
# Lat                          0
# dtype: int64

# %% [markdown]
# ---
# ## Explanation by data points comparison

# %% [markdown]
# ***Let's display the transaction data for a given credit card to check for any anomalies that might indicate fraudulent activity.***

# %%
filtered_df = df[df['credit_card'] == 1280981422329509]

# Create a map centered around the average location of the filtered data
if not filtered_df.empty:
    initial_location = [filtered_df['Lat'].mean(), filtered_df['Long'].mean()]
    transaction_map = folium.Map(location=initial_location, zoom_start=2)

    # Add markers for each transaction in the filtered data
    for index, row in filtered_df.iterrows():
        folium.Marker(
            location=[row['Lat'], row['Long']],
            tooltip=f"City: {row['city']}, State: {row['state']}",
            popup=f"Transaction: ${row['transaction_dollar_amount']} on {row['date']}"
        ).add_to(transaction_map)

    display(transaction_map)
else:
    print("No data found for the given credit card.")
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_850f8eb999a7c74674a09edd11b01da5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_850f8eb999a7c74674a09edd11b01da5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_850f8eb999a7c74674a09edd11b01da5 = L.map(
#                 &quot;map_850f8eb999a7c74674a09edd11b01da5&quot;,
#                 {
#                     center: [42.038583128704, -73.23997331441205],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0632ae4afead79eb4ce6852a030e79a9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_0632ae4afead79eb4ce6852a030e79a9.addTo(map_850f8eb999a7c74674a09edd11b01da5);
#
#
#             var marker_4a16a95f64db67c035a4bb0ca567a3f0 = L.marker(
#                 [41.3063130913948, -75.9368012278168],
#                 {}
#             ).addTo(map_850f8eb999a7c74674a09edd11b01da5);
#
#
#         var popup_6f5cdde676137c9dcb7c027f95c35e49 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2c8752b30ec0a8291f231637e18059cb = $(`&lt;div id=&quot;html_2c8752b30ec0a8291f231637e18059cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $8.14 on 2015-08-20 18:08:45&lt;/div&gt;`)[0];
#                 popup_6f5cdde676137c9dcb7c027f95c35e49.setContent(html_2c8752b30ec0a8291f231637e18059cb);
#
#
#
#         marker_4a16a95f64db67c035a4bb0ca567a3f0.bindPopup(popup_6f5cdde676137c9dcb7c027f95c35e49)
#         ;
#
#
#
#
#             marker_4a16a95f64db67c035a4bb0ca567a3f0.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b62f0ac0020431d9eb1e40b1240d910a = L.marker(
#                 [41.2966409463158, -76.0183170188432],
#                 {}
#             ).addTo(map_850f8eb999a7c74674a09edd11b01da5);
#
#
#         var popup_7ada470173d145850a0f7ce62329b615 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca17ddc6bf62ae39f856086100a4bae1 = $(`&lt;div id=&quot;html_ca17ddc6bf62ae39f856086100a4bae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $41.53 on 2015-08-31 19:16:27&lt;/div&gt;`)[0];
#                 popup_7ada470173d145850a0f7ce62329b615.setContent(html_ca17ddc6bf62ae39f856086100a4bae1);
#
#
#
#         marker_b62f0ac0020431d9eb1e40b1240d910a.bindPopup(popup_7ada470173d145850a0f7ce62329b615)
#         ;
#
#
#
#
#             marker_b62f0ac0020431d9eb1e40b1240d910a.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_5fc66d9476aaa557c91c62e06d6b1099 = L.marker(
#                 [41.349526258663, -75.9887228635778],
#                 {}
#             ).addTo(map_850f8eb999a7c74674a09edd11b01da5);
#
#
#         var popup_ce724c4eb76c5d2ac94bc71ec93a180a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9e848a2d90a57a88c38f8a96f6fb1afb = $(`&lt;div id=&quot;html_9e848a2d90a57a88c38f8a96f6fb1afb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $44.52 on 2015-10-15 16:48:33&lt;/div&gt;`)[0];
#                 popup_ce724c4eb76c5d2ac94bc71ec93a180a.setContent(html_9e848a2d90a57a88c38f8a96f6fb1afb);
#
#
#
#         marker_5fc66d9476aaa557c91c62e06d6b1099.bindPopup(popup_ce724c4eb76c5d2ac94bc71ec93a180a)
#         ;
#
#
#
#
#             marker_5fc66d9476aaa557c91c62e06d6b1099.bindTooltip(
#                 `&lt;div&gt;
#                      City: Dallas, State: PA
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_62d7477a844c89ee849e3f54d08edc58 = L.marker(
#                 [41.3212025234922, -76.0363474416275],
#                 {}
#             ).addTo(map_850f8eb999a7c74674a09edd11b01da5);
#
#
#         var popup_3e880558439c22581a7821135d2329e5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8cfc0fdbea73ca2997ddcdab1bfa000d = $(`&lt;div id=&quot;html_8cfc0fdbea73ca2997ddcdab1bfa000d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Transaction: $43.75 on 2015-09-23 17:46:27&lt;/div&gt;`)[0];
#                 popup_3e880558439c22581a7821135d2329e5.setContent(html_8cfc0fdbea73ca2997ddcdab1bfa000d);
#
#
#
#         marker_62d7477a844c89ee849e3f54d08edc58.bindPopup(popup_3e880558439c22581a7821135d2329e5)
#         ;
#
#
#
#
#             marker_62d7477a844c89ee849e3f54d08edc58.bindTooltip(

# %%
# Extract the 'transaction_dollar_amount' column from filtered_df
transaction_amounts = filtered_df['transaction_dollar_amount']

# Plot a histogram of transaction dollar amounts
plt.hist(transaction_amounts, bins=20, color='skyblue', edgecolor='black')

# Add labels and title
plt.xlabel('Transaction Dollar Amount')
plt.ylabel('Frequency')
plt.title('Distribution of Transaction Dollar Amounts')

# Show the plot
plt.show()

# %%
# Find the index of the transaction with the maximum dollar amount
max_transaction_index = filtered_df['transaction_dollar_amount'].idxmax()

# Get the 'lat' and 'long' values of the transaction with the maximum dollar amount
max_transaction_state = filtered_df.loc[max_transaction_index, 'city']

print("City of transaction with maximum dollar amount:", max_transaction_state)
# Out:
# City of transaction with maximum dollar amount: Dallas

# %%
plt.figure(figsize=(15, 7))
sns.histplot(df['transaction_dollar_amount'], kde=True)
plt.title('Histogram of Transaction Dollar Amount')
plt.xlabel('Transaction Dollar Amount')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ---
# ### For simplicity, from now on, we will use only the transactions dataset.

# %%
# Convert Date to Number
unix_timestamps = []

for date in df_trans['date']:
    datetime_obj = pd.to_datetime(date)
    unix_timestamp = int(datetime_obj.timestamp())
    unix_timestamps.append(unix_timestamp)

# Add the converted dates as a new column
df_trans['unix_timestamp'] = unix_timestamps
df_trans.drop(['date'], axis=1, inplace=True)


# Standardization
df_trans_columns = df_trans.columns
std = StandardScaler()
df_trans = std.fit_transform(df_trans)
df_trans = pd.DataFrame(df_trans, columns = df_trans_columns)

# %%
model = IsolationForest(n_estimators=100, max_samples=0.5,
                        contamination='auto', max_features=1.0, bootstrap=False, n_jobs=None,
                        verbose=1, random_state=2020)
model.fit(df_trans)
# Out:
# IsolationForest(max_samples=0.5, random_state=2020, verbose=1)

# %%
Y = model.predict(df_trans)

# %%
Y_series = pd.Series(Y)
print(Y_series.value_counts())
# Out:
#  1    282758
# -1     11830
# Name: count, dtype: int64

# %%
X_train_scaled_df = pd.DataFrame(df_trans, columns=df_trans.columns)

shap_sample = X_train_scaled_df.sample(500)
explainer = shap.Explainer(model.predict, shap_sample)
shap_values = explainer(shap_sample)
shap_values.feature_names = X_train_scaled_df.columns.tolist()
shap.plots.beeswarm(shap_values)
# Out:
# ExactExplainer explainer: 501it [01:08,  7.25it/s]

# %%
anomaly_indices = Y_series[Y_series == -1].index
anomaly_example_idx = anomaly_indices[0]
print(f"Anomaly Values: {df_trans.loc[anomaly_example_idx]}")
print(f"Anomaly Index: {anomaly_example_idx}")
# Out:
# Anomaly Values: credit_card                 -1.729732
# transaction_dollar_amount    0.073739
# Long                         3.645499
# Lat                         -1.148556
# unix_timestamp               0.121939
# Name: 8, dtype: float64
# Anomaly Index: 8

# %%
shap.plots.bar(explainer(X_train_scaled_df)[anomaly_example_idx])
# Out:
# ExactExplainer explainer:   2%|███▉                                                                                                                                                                 | 7105/294588 [16:18<11:07:21,  7.18it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 shap.plots.bar(explainer(X_train_scaled_df)[anomaly_example_idx])
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\explainers\_exact.py:75, in ExactExplainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, interactions, silent, *args)
#      72 """Explains the output of model(*args), where args represents one or more parallel iterators."""
#      73 # we entirely rely on the general call implementation, we override just to remove **kwargs
#      74 # from the function signature
# ---> 75 return super().__call__(
#      76     *args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#      77     batch_size=batch_size, interactions=interactions, silent=silent
#      78 )
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\explainers\_explainer.py:266, in Explainer.__call__(self, max_evals, main_effects, error_bounds, batch_size, outputs, silent, *args, **kwargs)
#     264     feature_names = [[] for _ in range(len(args))]
#     265 for row_args in show_progress(zip(*args), num_rows, self.__class__.__name__+" explainer", silent):
# --> 266     row_result = self.explain_row(
#     267         *row_args, max_evals=max_evals, main_effects=main_effects, error_bounds=error_bounds,
#     268         batch_size=batch_size, outputs=outputs, silent=silent, **kwargs
#     269     )
#     270     values.append(row_result.get("values", None))
#     271     output_indices.append(row_result.get("output_indices", None))
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\explainers\_exact.py:117, in ExactExplainer.explain_row(self, max_evals, main_effects, error_bounds, batch_size, outputs, interactions, silent, *row_args)
#     114         extended_delta_indexes[i] = inds[delta_indexes[i]]
#     116 # run the model
# --> 117 outputs = fm(extended_delta_indexes, zero_index=0, batch_size=batch_size)
#     119 # Shapley values
#     120 # Care: Need to distinguish between `True` and `1`
#     121 if interactions is False or (interactions == 1 and interactions is not True):
#     122
#     123     # loop over all the outputs to update the rows
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\utils\_masked_model.py:60, in MaskedModel.__call__(self, masks, zero_index, batch_size)
#      58 if len(masks.shape) == 1:
#      59     if getattr(self.masker, "supports_delta_masking", False):
# ---> 60         return self._delta_masking_call(masks, zero_index=zero_index, batch_size=batch_size)
#      62     # we need to convert from delta masking to a full masking call because we were given a delta masking
#      63     # input but the masker does not support delta masking
#      64     else:
#      65         full_masks = np.zeros((int(np.sum(masks >= 0)), self._masker_cols), dtype=bool)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\utils\_masked_model.py:206, in MaskedModel._delta_masking_call(self, masks, zero_index, batch_size)
#     203     batch_positions[i+1] = batch_positions[i] + num_varying_rows[i]
#     205 # joined_masked_inputs = self._stack_inputs(all_masked_inputs)
# --> 206 outputs = self.model(*subset_masked_inputs)
#     207 _assert_output_input_match(subset_masked_inputs, outputs)
#     209 if self.linearize_link and self.link != links.identity and self._linearizing_weights is None:
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\shap\models\_model.py:21, in Model.__call__(self, *args)
#      20 def __call__(self, *args):
# ---> 21     out = self.inner_model(*args)
#      22     is_tensor = safe_isinstance(out, "torch.Tensor")
#      23     out = out.cpu().detach().numpy() if is_tensor else np.array(out)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:369, in IsolationForest.predict(self, X)
#     352 """
#     353 Predict if a particular sample is an outlier or not.
#     354
#    (...)
#     366     be considered as an inlier according to the fitted model.
#     367 """
#     368 check_is_fitted(self)
# --> 369 decision_func = self.decision_function(X)
#     370 is_inlier = np.ones_like(decision_func, dtype=int)
#     371 is_inlier[decision_func < 0] = -1
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:404, in IsolationForest.decision_function(self, X)
#     375 """
#     376 Average anomaly score of X of the base classifiers.
#     377
#    (...)
#     399     positive scores represent inliers.
#     400 """
#     401 # We subtract self.offset_ to make 0 be the threshold value for being
#     402 # an outlier:
# --> 404 return self.score_samples(X) - self.offset_
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:433, in IsolationForest.score_samples(self, X)
#     430 # Check data
#     431 X = self._validate_data(X, accept_sparse="csr", dtype=tree_dtype, reset=False)
# --> 433 return self._score_samples(X)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:445, in IsolationForest._score_samples(self, X)
#     442 check_is_fitted(self)
#     444 # Take the opposite of the scores as bigger is better (here less abnormal)
# --> 445 return -self._compute_chunked_score_samples(X)
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:475, in IsolationForest._compute_chunked_score_samples(self, X)
#     471 scores = np.zeros(n_samples, order="f")
#     473 for sl in slices:
#     474     # compute score on the slices of test samples:
# --> 475     scores[sl] = self._compute_score_samples(X[sl], subsample_features)
#     477 return scores
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\ensemble\_iforest.py:502, in IsolationForest._compute_score_samples(self, X, subsample_features)
#     497 for tree_idx, (tree, features) in enumerate(
#     498     zip(self.estimators_, self.estimators_features_)
#     499 ):
#     500     X_subset = X[:, features] if subsample_features else X
# --> 502     leaves_index = tree.apply(X_subset, check_input=False)
#     504     depths += (
#     505         self._decision_path_lengths[tree_idx][leaves_index]
#     506         + self._average_path_length_per_tree[tree_idx][leaves_index]
#     507         - 1.0
#     508     )
#     509 denominator = len(self.estimators_) * average_path_length_max_samples
#
# File ~\PycharmProjects\MSc\Deep_Generative_Models\Amit\.venv\lib\site-packages\sklearn\tree\_classes.py:582, in BaseDecisionTree.apply(self, X, check_input)
#     580 check_is_fitted(self)
#     581 X = self._validate_X_predict(X, check_input)
# --> 582 return self.tree_.apply(X)
#
# KeyboardInterrupt:
